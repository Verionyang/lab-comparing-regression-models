# %% [markdown]
# # Week4 Day 1 Morning Lab

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
customer_df = pd.read_csv('customer_value_analysis.csv')
display(customer_df.shape)
display(customer_df.info())
customer_df.head()
# Out:
# (9134, 24)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       9134 non-null   object
#  1   State                          9134 non-null   object
#  2   Customer Lifetime Value        9134 non-null   float64
#  3   Response                       9134 non-null   object
#  4   Coverage                       9134 non-null   object
#  5   Education                      9134 non-null   object
#  6   Effective To Date              9134 non-null   object
#  7   EmploymentStatus               9134 non-null   object
#  8   Gender                         9134 non-null   object
#  9   Income                         9134 non-null   int64
#  10  Location Code                  9134 non-null   object
#  11  Marital Status                 9134 non-null   object
#  12  Monthly Premium Auto           9134 non-null   int64
#  13  Months Since Last Claim        9134 non-null   int64
#  14  Months Since Policy Inception  9134 non-null   int64
#  15  Number of Open Complaints      9134 non-null   int64
#  16  Number of Policies             9134 non-null   int64
#  17  Policy Type                    9134 non-null   object
#  18  Policy                         9134 non-null   object
#  19  Renew Offer Type               9134 non-null   object
#  20  Sales Channel                  9134 non-null   object
#  21  Total Claim Amount             9134 non-null   float64
#  22  Vehicle Class                  9134 non-null   object
#  23  Vehicle Size                   9134 non-null   object
# dtypes: float64(2), int64(6), object(16)
# memory usage: 1.7+ MB
# None
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       Policy Type        Policy  Renew Offer Type  Sales Channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   Total Claim Amount  Vehicle Class Vehicle Size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
col = []
for column in customer_df.columns: 
    col.append(str(column).lower().replace(" ","_"))

customer_df.columns = col

customer_df.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer_df['effective_to_date']=pd.to_datetime(customer_df['effective_to_date'])
display(customer_df.info())
customer_df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9134 entries, 0 to 9133
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       9134 non-null   object
#  1   state                          9134 non-null   object
#  2   customer_lifetime_value        9134 non-null   float64
#  3   response                       9134 non-null   object
#  4   coverage                       9134 non-null   object
#  5   education                      9134 non-null   object
#  6   effective_to_date              9134 non-null   datetime64[ns]
#  7   employmentstatus               9134 non-null   object
#  8   gender                         9134 non-null   object
#  9   income                         9134 non-null   int64
#  10  location_code                  9134 non-null   object
#  11  marital_status                 9134 non-null   object
#  12  monthly_premium_auto           9134 non-null   int64
#  13  months_since_last_claim        9134 non-null   int64
#  14  months_since_policy_inception  9134 non-null   int64
#  15  number_of_open_complaints      9134 non-null   int64
#  16  number_of_policies             9134 non-null   int64
#  17  policy_type                    9134 non-null   object
#  18  policy                         9134 non-null   object
#  19  renew_offer_type               9134 non-null   object
#  20  sales_channel                  9134 non-null   object
#  21  total_claim_amount             9134 non-null   float64
#  22  vehicle_class                  9134 non-null   object
#  23  vehicle_size                   9134 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(6), object(15)
# memory usage: 1.7+ MB
# None
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
# 2                            38                         0                   2
# 3                            65                         0                   7
# 4                            44                         0                   1
#
#       policy_type        policy  renew_offer_type  sales_channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
# 2   Personal Auto   Personal L3            Offer1          Agent
# 3  Corporate Auto  Corporate L2            Offer1    Call Center
# 4   Personal Auto   Personal L1            Offer1          Agent
#
#   total_claim_amount  vehicle_class vehicle_size
# 0         384.811147   Two-Door Car      Medsize
# 1        1131.464935  Four-Door Car      Medsize
# 2         566.472247   Two-Door Car      Medsize
# 3         529.881344            SUV      Medsize
# 4         138.130879  Four-Door Car      Medsize
#
# [5 rows x 24 columns]

# %%
customer_df.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %%
def num_cat_split(df):
    df_num = df.select_dtypes(include = np.number)
    df_cat = df.select_dtypes(include = 'object')
    return df_num, df_cat

# %%
customer_num,customer_cat = num_cat_split(customer_df)

# %%
customer_cat = customer_cat.drop(columns="customer",axis=1)
customer_cat.head(5)
# Out:
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status     policy_type        policy renew_offer_type  \
# 0      Suburban        Married  Corporate Auto  Corporate L3           Offer1
# 1      Suburban         Single   Personal Auto   Personal L3           Offer3
# 2      Suburban        Married   Personal Auto   Personal L3           Offer1
# 3      Suburban        Married  Corporate Auto  Corporate L2           Offer1
# 4         Rural         Single   Personal Auto   Personal L1           Offer1
#
#   sales_channel  vehicle_class vehicle_size
# 0         Agent   Two-Door Car      Medsize
# 1         Agent  Four-Door Car      Medsize
# 2         Agent   Two-Door Car      Medsize
# 3   Call Center            SUV      Medsize
# 4         Agent  Four-Door Car      Medsize

# %%
fig,ax = plt.subplots(figsize=(7,6))
sns.heatmap(customer_num.corr(),annot=True)
plt.show()

# %% [markdown]
# The pair of monthly premiums of the auto and the total claim has the highest correlation. It suggests that the higher the premium cost is, the higher the total claim amount is. A higher premium implies a better insurance package so the drivers can declare more claims and get more money in return.

# %%
def con_dis_split(df, thr=36):
    con = []
    dis = []
    for i in range(df.shape[1]):
        if df.iloc[:,i].unique().size >=thr: 
            con.append(i)
        else: 
            dis.append(i)
    return df.iloc[:,con],df.iloc[:, dis]

# %%
customer_con,customer_dis = con_dis_split(customer_num)

display(customer_con.head(5))
customer_dis.head(5)
# Out:
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    months_since_last_claim  months_since_policy_inception  total_claim_amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879
#    number_of_open_complaints  number_of_policies
# 0                          0                   1
# 1                          0                   8
# 2                          0                   2
# 3                          0                   7
# 4                          0                   1

# %%
def barplot_df(df):
    fig,ax = plt.subplots(1,df.shape[1],figsize=(16,16))
    for i in range(0,df.shape[1]):
        unique_values = df.iloc[:,i].unique().size
        if (unique_values <= 6):
            sns.countplot(x=df.iloc[:,i], order=df.iloc[:,i].value_counts().index,ax=ax[i])
        else:
            sns.countplot(y=df.iloc[:,i], order=df.iloc[:,i].value_counts().index,ax=ax[i])
    return fig

# %%
fig1 = barplot_df(customer_dis)

# %%
def histplot_df(df):
    fig,ax = plt.subplots(1,df.shape[1],figsize=(16,16))
    for i in range(0,df.shape[1]):
        sns.histplot(x=df.iloc[:,i],ax=ax[i])
    return fig

# %%
fig2 = histplot_df(customer_con)

# %% [markdown]
# I will apply power transformation to the continous variables to change the pattern so they are closer to Gaussian..

# %%
def boxplot_df(df):
    fig,ax = plt.subplots(1,df.shape[1],figsize=(16,16))
    for i in range(0,df.shape[1]):
        sns.boxplot(y=df.iloc[:,i],ax=ax[i])
    return fig

# %%
fig3 = boxplot_df(customer_con)

# %% [markdown]
# # Week4 Day 1 Afternoon lab

# %%
def countplot_df(df):
    for i in range(0,df.shape[1]):
        unique_values = df.iloc[:,i].unique().size
        if (unique_values <= 6):
            sns.countplot(x=df.iloc[:,i], order=df.iloc[:,i].value_counts().index)
        else:
            sns.countplot(y=df.iloc[:,i], order=df.iloc[:,i].value_counts().index)
        plt.show()

# %%
fig4  = countplot_df(customer_cat)
fig4

# %%
customer_cat = customer_cat.drop(columns=['policy_type'],axis=1)

def clean_policy(x):
    x=str(x)
    if 'L1' in x:
        x = 'L1'
    elif 'L2' in x:
        x = 'L2'
    else: 
        x = 'L3'
    return x

customer_cat['policy']=customer_cat['policy'].apply(clean_policy)

display(customer_cat['policy'].value_counts(dropna=False))
customer_cat.head(5)
# Out:
# L3    4588
# L2    2881
# L1    1665
# Name: policy, dtype: int64
#         state response  coverage education employmentstatus gender  \
# 0  Washington       No     Basic  Bachelor         Employed      F
# 1     Arizona       No  Extended  Bachelor       Unemployed      F
# 2      Nevada       No   Premium  Bachelor         Employed      F
# 3  California       No     Basic  Bachelor       Unemployed      M
# 4  Washington       No     Basic  Bachelor         Employed      M
#
#   location_code marital_status policy renew_offer_type sales_channel  \
# 0      Suburban        Married     L3           Offer1         Agent
# 1      Suburban         Single     L3           Offer3         Agent
# 2      Suburban        Married     L3           Offer1         Agent
# 3      Suburban        Married     L2           Offer1   Call Center
# 4         Rural         Single     L1           Offer1         Agent
#
#    vehicle_class vehicle_size
# 0   Two-Door Car      Medsize
# 1  Four-Door Car      Medsize
# 2   Two-Door Car      Medsize
# 3            SUV      Medsize
# 4  Four-Door Car      Medsize

# %%
fig,ax=plt.subplots(figsize=(10,10))
sns.lineplot(data=customer_df,x='effective_to_date',y='total_claim_amount')
plt.show()

# %%
df_new = pd.DataFrame(columns=['day','day_name','week','month','total_claim_amount'])

# %%
df_new['day']=customer_df['effective_to_date'].dt.strftime('%d')
df_new['day_name']=customer_df['effective_to_date'].dt.day_name()
df_new['month']=customer_df['effective_to_date'].dt.strftime('%B')
df_new['week']=customer_df['effective_to_date'].dt.isocalendar().week
df_new['total_claim_amount']=customer_df['total_claim_amount']
display(df_new.shape)
display(df_new.isna().sum())
df_new.head(5)
# Out:
# (9134, 5)
# day                   0
# day_name              0
# week                  0
# month                 0
# total_claim_amount    0
# dtype: int64
#   day  day_name  week     month  total_claim_amount
# 0  24  Thursday     8  February          384.811147
# 1  31    Monday     5   January         1131.464935
# 2  19  Saturday     7  February          566.472247
# 3  20  Thursday     3   January          529.881344
# 4  03  Thursday     5  February          138.130879

# %%
target = df_new.groupby('day_name').agg({'total_claim_amount':sum}).round(2).reindex(index=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
target
# Out:
#            total_claim_amount
# day_name
# Monday              655689.71
# Tuesday             502518.93
# Wednesday           541563.05
# Thursday            541820.80
# Friday              533658.79
# Saturday            608060.10
# Sunday              581655.66

# %%
fig,ax=plt.subplots(figsize=(10,10))
sns.lineplot(data=target,x='day_name',y='total_claim_amount')
plt.show()

# %% [markdown]
# ### Monday has the highest claims, followed by both weekend days while Tuesday has the least amount of claims.

# %%
target2 = df_new.groupby('day_name').agg({'total_claim_amount':np.median}).round(2).reindex(index=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
target2.sort_values('total_claim_amount',ascending=False)
# Out:
#            total_claim_amount
# day_name
# Thursday               395.33
# Wednesday              392.24
# Monday                 385.74
# Sunday                 383.72
# Saturday               379.20
# Tuesday                378.49
# Friday                 371.80

# %%
fig,ax=plt.subplots(figsize=(10,10))
sns.lineplot(data=target2,x='day_name',y='total_claim_amount')
plt.show()

# %% [markdown]
# ### Wednesday and Thursday have the highest median claims but the total sums are both relatively low. It may suggest the following:
# 1. Weekends and Monday have the most claims but mostly are minor issues - the median amount per claim is relatively lower
# 2. Wednesdays and Thursdays, despite not being the busiest days of the week, will more likely get a higher claim amount.
# 3. Tuesday and Friday are in general quieter with Friday being the least busy day of the week in terms of median value per claim and Tuesday being the least busy day in terms of volumne.

# %%
target3 = df_new.groupby('month').agg({'total_claim_amount':np.median}).round(2)
target3.sort_values('total_claim_amount',ascending=False)
# Out:
#           total_claim_amount
# month
# February              385.28
# January               381.40

# %% [markdown]
# ### Since the dataset only collects two months of data. It is hard to draw conclusions on other months.

# %%
customer_con.describe().T
# Out:
#                                 count          mean           std  \
# customer_lifetime_value        9134.0   8004.940475   6870.967608
# income                         9134.0  37657.380009  30379.904734
# monthly_premium_auto           9134.0     93.219291     34.407967
# months_since_last_claim        9134.0     15.097000     10.073257
# months_since_policy_inception  9134.0     48.064594     27.905991
# total_claim_amount             9134.0    434.088794    290.500092
#
#                                        min          25%           50%  \
# customer_lifetime_value        1898.007675  3994.251794   5780.182197
# income                            0.000000     0.000000  33889.500000
# monthly_premium_auto             61.000000    68.000000     83.000000
# months_since_last_claim           0.000000     6.000000     14.000000
# months_since_policy_inception     0.000000    24.000000     48.000000
# total_claim_amount                0.099007   272.258244    383.945434
#
#                                         75%           max
# customer_lifetime_value         8962.167041  83325.381190
# income                         62320.000000  99981.000000
# monthly_premium_auto             109.000000    298.000000
# months_since_last_claim           23.000000     35.000000
# months_since_policy_inception     71.000000     99.000000
# total_claim_amount               547.514839   2893.239678

# %%
customer2 = customer_con.copy()

customer2['income']=customer2['income'][customer2['income']>150] 
display(customer_con['income'].head())
customer2['income'].head()
# Out:
# 0    56274
# 1        0
# 2    48767
# 3        0
# 4    43836
# Name: income, dtype: int64
# 0    56274.0
# 1        NaN
# 2    48767.0
# 3        NaN
# 4    43836.0
# Name: income, dtype: float64

# %%
def clean_outliers(df,col):
    max_thr = (int(df[col].quantile([0.75]))-int(df[col].quantile([0.25])))*1.5+int(df[col].quantile([0.75]))
    df[col]=df[col][df[col]<=max_thr]
    return df[col]

# %%
continuous_cleaned_df = customer_con.copy()

# %%
continuous_cleaned_df['customer_lifetime_value']=clean_outliers(continuous_cleaned_df,'customer_lifetime_value')
continuous_cleaned_df['income']=clean_outliers(continuous_cleaned_df,'income')
continuous_cleaned_df['monthly_premium_auto']=clean_outliers(continuous_cleaned_df,'monthly_premium_auto')
continuous_cleaned_df['months_since_last_claim']=clean_outliers(continuous_cleaned_df,'months_since_last_claim')
continuous_cleaned_df['months_since_policy_inception']=clean_outliers(continuous_cleaned_df,'months_since_policy_inception')
continuous_cleaned_df['total_claim_amount']=clean_outliers(continuous_cleaned_df,'total_claim_amount')
continuous_cleaned_df.isna().sum()
# Out:
# customer_lifetime_value          817
# income                             0
# monthly_premium_auto             430
# months_since_last_claim            0
# months_since_policy_inception      0
# total_claim_amount               460
# dtype: int64

# %%
df_new_2 = df_new.drop(columns=['day','week','total_claim_amount'],axis=1)
continuous_cleaned_df = continuous_cleaned_df.drop(columns='total_claim_amount',axis=1)

data1 = pd.concat([continuous_cleaned_df,df_new_2,customer_dis,customer_cat,customer_con['total_claim_amount']],axis=1)
display(data1.shape)
data1.head(5)
# Out:
# (9134, 23)
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                  69.0
# 1              6979.535903       0                  94.0
# 2             12887.431650   48767                 108.0
# 3              7645.861827       0                 106.0
# 4              2813.692575   43836                  73.0
#
#    months_since_last_claim  months_since_policy_inception  day_name     month  \
# 0                       32                              5  Thursday  February
# 1                       13                             42    Monday   January
# 2                       18                             38  Saturday  February
# 3                       18                             65  Thursday   January
# 4                       12                             44  Thursday  February
#
#    number_of_open_complaints  number_of_policies       state  ...  \
# 0                          0                   1  Washington  ...
# 1                          0                   8     Arizona  ...
# 2                          0                   2      Nevada  ...
# 3                          0                   7  California  ...
# 4                          0                   1  Washington  ...
#
#   employmentstatus gender location_code marital_status policy  \
# 0         Employed      F      Suburban        Married     L3
# 1       Unemployed      F      Suburban         Single     L3
# 2         Employed      F      Suburban        Married     L3
# 3       Unemployed      M      Suburban        Married     L2
# 4         Employed      M         Rural         Single     L1
#
#   renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0           Offer1         Agent   Two-Door Car      Medsize
# 1           Offer3         Agent  Four-Door Car      Medsize
# 2           Offer1         Agent   Two-Door Car      Medsize
# 3           Offer1   Call Center            SUV      Medsize
# 4           Offer1         Agent  Four-Door Car      Medsize
#
#   total_claim_amount
# 0         384.811147
# 1        1131.464935
# 2         566.472247
# 3         529.881344
# 4         138.130879
#
# [5 rows x 23 columns]

# %%
data1 = data1.dropna().reset_index(drop=True)
display(data1.shape)
data1.head(5)
# Out:
# (8033, 23)
#    customer_lifetime_value  income  monthly_premium_auto  \
# 0              2763.519279   56274                  69.0
# 1              6979.535903       0                  94.0
# 2             12887.431650   48767                 108.0
# 3              7645.861827       0                 106.0
# 4              2813.692575   43836                  73.0
#
#    months_since_last_claim  months_since_policy_inception  day_name     month  \
# 0                       32                              5  Thursday  February
# 1                       13                             42    Monday   January
# 2                       18                             38  Saturday  February
# 3                       18                             65  Thursday   January
# 4                       12                             44  Thursday  February
#
#    number_of_open_complaints  number_of_policies       state  ...  \
# 0                          0                   1  Washington  ...
# 1                          0                   8     Arizona  ...
# 2                          0                   2      Nevada  ...
# 3                          0                   7  California  ...
# 4                          0                   1  Washington  ...
#
#   employmentstatus gender location_code marital_status policy  \
# 0         Employed      F      Suburban        Married     L3
# 1       Unemployed      F      Suburban         Single     L3
# 2         Employed      F      Suburban        Married     L3
# 3       Unemployed      M      Suburban        Married     L2
# 4         Employed      M         Rural         Single     L1
#
#   renew_offer_type sales_channel  vehicle_class vehicle_size  \
# 0           Offer1         Agent   Two-Door Car      Medsize
# 1           Offer3         Agent  Four-Door Car      Medsize
# 2           Offer1         Agent   Two-Door Car      Medsize
# 3           Offer1   Call Center            SUV      Medsize
# 4           Offer1         Agent  Four-Door Car      Medsize
#
#   total_claim_amount
# 0         384.811147
# 1        1131.464935
# 2         566.472247
# 3         529.881344
# 4         138.130879
#
# [5 rows x 23 columns]

# %%
def clean_response(x):
    x=str(x)
    if x == 'Yes':
        x=1
    else:
        x=0
    return x

# %%
data1['response']=data1['response'].apply(clean_response)
data1['response'].value_counts()
# Out:
# 0    6875
# 1    1158
# Name: response, dtype: int64

# %%
display(data1['education'].value_counts())


def clean_education(x):
    x = str(x)
    if x in ["Master","Doctor"]:
        x = "Graduate"
    else: 
        x=x
    return x



data1['education']=data1['education'].apply(clean_education)
data1['education'].value_counts()
# Out:
# Bachelor                2411
# College                 2391
# High School or Below    2275
# Master                   646
# Doctor                   310
# Name: education, dtype: int64
# Bachelor                2411
# College                 2391
# High School or Below    2275
# Graduate                 956
# Name: education, dtype: int64

# %%
display(data1['employmentstatus'].value_counts())


def clean_employment(x):
    x = str(x)
    if x in ["Medical Leave", "Disabled", "Retired"]:
        x = "Inactive"
    else: 
        x=x
    return x



data1['employmentstatus']=data1['employmentstatus'].apply(clean_employment)
data1['employmentstatus'].value_counts()
# Out:
# Employed         4994
# Unemployed       2043
# Medical Leave     388
# Disabled          357
# Retired           251
# Name: employmentstatus, dtype: int64
# Employed      4994
# Unemployed    2043
# Inactive       996
# Name: employmentstatus, dtype: int64

# %%
display(data1['gender'].value_counts())
data1['gender']=data1['gender'].apply(lambda x: 1 if x=='F' else 0)
data1['gender'].value_counts()
# Out:
# F    4079
# M    3954
# Name: gender, dtype: int64
# 1    4079
# 0    3954
# Name: gender, dtype: int64

# %%
display(data1['vehicle_class'].value_counts())


def clean_vehicle_class(x):
    x = str(x)
    if x in ["Sports Car", "Luxury SUV", "Luxury Car"]:
        x = "Luxury"
    else: 
        x=x
    return x



data1['vehicle_class']=data1['vehicle_class'].apply(clean_vehicle_class)
data1['vehicle_class'].value_counts()
# Out:
# Four-Door Car    4331
# Two-Door Car     1763
# SUV              1532
# Sports Car        407
# Name: vehicle_class, dtype: int64
# Four-Door Car    4331
# Two-Door Car     1763
# SUV              1532
# Luxury            407
# Name: vehicle_class, dtype: int64

# %%
display(data1['employmentstatus'].value_counts())
def ordinal_employ(x):
    if x == 'Employed':
        x=3
    elif x == 'Inactive':
        x=2
    else:
        x=1
    return x
data1['employmentstatus']=data1['employmentstatus'].apply(ordinal_employ)
data1['employmentstatus'].value_counts()
# Out:
# Employed      4994
# Unemployed    2043
# Inactive       996
# Name: employmentstatus, dtype: int64
# 3    4994
# 1    2043
# 2     996
# Name: employmentstatus, dtype: int64

# %%
display(data1['location_code'].value_counts())
def ordinal_location(x):
    if x == 'Urban':
        x=3
    elif x == 'Suburban':
        x=2
    else:
        x=1
    return x
data1['location_code']=data1['location_code'].apply(ordinal_location)
data1['location_code'].value_counts()
# Out:
# Suburban    5043
# Rural       1576
# Urban       1414
# Name: location_code, dtype: int64
# 2    5043
# 1    1576
# 3    1414
# Name: location_code, dtype: int64

# %%
display(data1['vehicle_size'].value_counts())
def ordinal_vehicle_size(x):
    if x == 'Large':
        x=3
    elif x == 'Medsize':
        x=2
    else:
        x=1
    return x
data1['vehicle_size']=data1['vehicle_size'].apply(ordinal_vehicle_size)
data1['vehicle_size'].value_counts()
# Out:
# Medsize    5643
# Small      1545
# Large       845
# Name: vehicle_size, dtype: int64
# 2    5643
# 1    1545
# 3     845
# Name: vehicle_size, dtype: int64

# %%
display(data1['day_name'].value_counts())
def group_weekday(x):
    if x in ['Saturday','Sunday']:
        x='Weekend'
    else:
        x='Weekday'
    return x
data1['day_name']=data1['day_name'].apply(group_weekday)
data1['day_name'].value_counts()
# Out:
# Monday       1350
# Saturday     1218
# Sunday       1164
# Thursday     1109
# Friday       1096
# Wednesday    1085
# Tuesday      1011
# Name: day_name, dtype: int64
# Weekday    5651
# Weekend    2382
# Name: day_name, dtype: int64

# %%
data1_cat=data1.select_dtypes('object')
data1_cat
# Out:
#      day_name     month       state  coverage education marital_status policy  \
# 0     Weekday  February  Washington     Basic  Bachelor        Married     L3
# 1     Weekday   January     Arizona  Extended  Bachelor         Single     L3
# 2     Weekend  February      Nevada   Premium  Bachelor        Married     L3
# 3     Weekday   January  California     Basic  Bachelor        Married     L2
# 4     Weekday  February  Washington     Basic  Bachelor         Single     L1
# ...       ...       ...         ...       ...       ...            ...    ...
# 8028  Weekday   January  California   Premium   College         Single     L2
# 8029  Weekend  February  California  Extended   College       Divorced     L3
# 8030  Weekend  February  California  Extended  Bachelor         Single     L2
# 8031  Weekday  February  California  Extended   College        Married     L2
# 8032  Weekday  February  California  Extended   College         Single     L3
#
#      renew_offer_type sales_channel  vehicle_class
# 0              Offer1         Agent   Two-Door Car
# 1              Offer3         Agent  Four-Door Car
# 2              Offer1         Agent   Two-Door Car
# 3              Offer1   Call Center            SUV
# 4              Offer1         Agent  Four-Door Car
# ...               ...           ...            ...
# 8028           Offer1        Branch  Four-Door Car
# 8029           Offer1        Branch  Four-Door Car
# 8030           Offer1        Branch  Four-Door Car
# 8031           Offer3        Branch  Four-Door Car
# 8032           Offer4   Call Center   Two-Door Car
#
# [8033 rows x 10 columns]

# %%
levels = data1_cat.values.tolist()

# %% [markdown]
# # Week4 Day 2 Morning lab

# %%
X = data1.drop(columns='total_claim_amount',axis=1)
y = data1['total_claim_amount']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=31)

# %%
X_train_num = X_train.select_dtypes(include = np.number)
X_test_num = X_test.select_dtypes(include = np.number)
X_train_cat = X_train.select_dtypes(include = 'object')
X_test_cat = X_test.select_dtypes(include = 'object')

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first')
encoder.fit(X_train_cat)
encoded = encoder.transform(X_train_cat).toarray()
X_train_coded = pd.DataFrame(encoded,columns=encoder.get_feature_names_out(),index=X_train_cat.index)
X_train_coded.head()
# Out:
#       day_name_Weekend  month_January  state_California  state_Nevada  \
# 6733               0.0            0.0               0.0           1.0
# 4793               0.0            0.0               0.0           0.0
# 7866               0.0            1.0               1.0           0.0
# 866                0.0            1.0               0.0           0.0
# 1827               0.0            0.0               0.0           0.0
#
#       state_Oregon  state_Washington  coverage_Extended  coverage_Premium  \
# 6733           0.0               0.0                1.0               0.0
# 4793           0.0               1.0                1.0               0.0
# 7866           0.0               0.0                0.0               1.0
# 866            0.0               0.0                0.0               0.0
# 1827           1.0               0.0                0.0               0.0
#
#       education_College  education_Graduate  ...  policy_L3  \
# 6733                0.0                 0.0  ...        1.0
# 4793                0.0                 0.0  ...        1.0
# 7866                0.0                 0.0  ...        1.0
# 866                 0.0                 0.0  ...        0.0
# 1827                0.0                 0.0  ...        1.0
#
#       renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 6733                      0.0                      0.0
# 4793                      0.0                      1.0
# 7866                      0.0                      0.0
# 866                       1.0                      0.0
# 1827                      1.0                      0.0
#
#       renew_offer_type_Offer4  sales_channel_Branch  \
# 6733                      0.0                   0.0
# 4793                      0.0                   0.0
# 7866                      0.0                   0.0
# 866                       0.0                   1.0
# 1827                      0.0                   0.0
#
#       sales_channel_Call Center  sales_channel_Web  vehicle_class_Luxury  \
# 6733                        0.0                1.0                   0.0
# 4793                        0.0                0.0                   0.0
# 7866                        0.0                0.0                   0.0
# 866                         0.0                0.0                   0.0
# 1827                        0.0                1.0                   0.0
#
#       vehicle_class_SUV  vehicle_class_Two-Door Car
# 6733                1.0                         0.0
# 4793                0.0                         0.0
# 7866                0.0                         0.0
# 866                 0.0                         1.0
# 1827                0.0                         0.0
#
# [5 rows x 24 columns]

# %%
encoded2 = encoder.transform(X_test_cat).toarray()
X_test_coded = pd.DataFrame(encoded2,columns=encoder.get_feature_names_out(),index=X_test_cat.index)
X_test_coded.head()
# Out:
#       day_name_Weekend  month_January  state_California  state_Nevada  \
# 3048               0.0            1.0               0.0           0.0
# 2904               0.0            1.0               0.0           0.0
# 7796               0.0            0.0               1.0           0.0
# 6448               1.0            1.0               1.0           0.0
# 4029               0.0            0.0               1.0           0.0
#
#       state_Oregon  state_Washington  coverage_Extended  coverage_Premium  \
# 3048           1.0               0.0                0.0               0.0
# 2904           1.0               0.0                0.0               0.0
# 7796           0.0               0.0                0.0               0.0
# 6448           0.0               0.0                0.0               0.0
# 4029           0.0               0.0                1.0               0.0
#
#       education_College  education_Graduate  ...  policy_L3  \
# 3048                1.0                 0.0  ...        1.0
# 2904                0.0                 0.0  ...        1.0
# 7796                0.0                 1.0  ...        1.0
# 6448                0.0                 0.0  ...        0.0
# 4029                0.0                 0.0  ...        0.0
#
#       renew_offer_type_Offer2  renew_offer_type_Offer3  \
# 3048                      1.0                      0.0
# 2904                      1.0                      0.0
# 7796                      0.0                      1.0
# 6448                      1.0                      0.0
# 4029                      1.0                      0.0
#
#       renew_offer_type_Offer4  sales_channel_Branch  \
# 3048                      0.0                   0.0
# 2904                      0.0                   0.0
# 7796                      0.0                   0.0
# 6448                      0.0                   0.0
# 4029                      0.0                   0.0
#
#       sales_channel_Call Center  sales_channel_Web  vehicle_class_Luxury  \
# 3048                        0.0                0.0                   0.0
# 2904                        0.0                1.0                   0.0
# 7796                        0.0                1.0                   0.0
# 6448                        0.0                0.0                   0.0
# 4029                        0.0                0.0                   0.0
#
#       vehicle_class_SUV  vehicle_class_Two-Door Car
# 3048                0.0                         0.0
# 2904                0.0                         0.0
# 7796                0.0                         1.0
# 6448                0.0                         0.0
# 4029                0.0                         0.0
#
# [5 rows x 24 columns]

# %%
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer()
pt.fit(X_train_num)
X_train_pt_np = pt.transform(X_train_num)
X_train_pt = pd.DataFrame(X_train_pt_np,columns=X_train_num.columns,index=X_train_num.index)
X_train_pt.head()
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 6733                -0.272673 -1.646387              1.534412
# 4793                 0.251298 -1.646387              0.259430
# 7866                 1.647596  0.321635              0.911343
# 866                 -0.198769 -1.646387             -1.064714
# 1827                -1.513060  0.041510             -0.671696
#
#       months_since_last_claim  months_since_policy_inception  \
# 6733                 0.078370                       1.467383
# 4793                 0.262320                       1.180989
# 7866                 0.436597                      -1.849404
# 866                  0.171662                       0.353016
# 1827                -0.017816                      -0.800564
#
#       number_of_open_complaints  number_of_policies  response  \
# 6733                   2.032622           -1.098886 -0.414075
# 4793                  -0.502493            1.529745 -0.414075
# 7866                  -0.502493           -0.077576 -0.414075
# 866                   -0.502493            0.479116 -0.414075
# 1827                  -0.502493           -1.098886  2.415020
#
#       employmentstatus    gender  location_code  vehicle_size
# 6733         -1.495971  0.978012      -1.622241      0.141985
# 4793         -1.495971  0.978012       0.038965      0.141985
# 7866          0.761967  0.978012       0.038965      0.141985
# 866          -1.495971  0.978012       0.038965      0.141985
# 1827         -0.769554 -1.022483       0.038965      0.141985

# %%
X_test_pt_np = pt.transform(X_test_num)
X_test_pt = pd.DataFrame(X_test_pt_np,columns=X_test_num.columns,index=X_test_num.index)
X_test_pt.head()
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 3048                 1.409173 -1.646387             -1.240718
# 2904                 0.589055  0.746148             -1.528357
# 7796                -1.299080  0.402139             -0.745414
# 6448                 1.235156  0.833853             -1.333289
# 4029                -1.137850 -1.646387              0.305437
#
#       months_since_last_claim  months_since_policy_inception  \
# 3048                 0.078370                       1.410827
# 2904                -0.438639                      -1.719175
# 7796                -0.017816                       0.188389
# 6448                -1.261934                      -0.719284
# 4029                 1.273415                      -1.012437
#
#       number_of_open_complaints  number_of_policies  response  \
# 3048                  -0.502493           -0.077576 -0.414075
# 2904                  -0.502493           -0.077576 -0.414075
# 7796                  -0.502493           -1.098886 -0.414075
# 6448                  -0.502493           -0.077576 -0.414075
# 4029                  -0.502493           -1.098886 -0.414075
#
#       employmentstatus    gender  location_code  vehicle_size
# 3048         -1.495971  0.978012       0.038965      0.141985
# 2904          0.761967 -1.022483      -1.622241      0.141985
# 7796          0.761967 -1.022483       1.663326      0.141985
# 6448          0.761967 -1.022483       1.663326      2.058132
# 4029         -1.495971 -1.022483       0.038965     -1.690237

# %%
X_train_new =pd.concat([X_train_pt,X_train_coded],axis=1)
X_test_new = pd.concat([X_test_pt,X_test_coded],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train_new)

X_train_normalised = scaler.transform(X_train_new)
X_train_new_scaled_df = pd.DataFrame(X_train_normalised,columns=X_train_new.columns,index=X_train_new.index)
X_test_normalised = scaler.transform(X_test_new)
X_test_new_scaled_df = pd.DataFrame(X_test_normalised,columns=X_test_new.columns,index=X_test_new.index)

# %%
display(X_train_new_scaled_df.head())
X_test_new_scaled_df.head()
# Out:
#       customer_lifetime_value    income  monthly_premium_auto  \
# 6733                 0.428698  0.000000              0.837003
# 4793                 0.551186  0.000000              0.488572
# 7866                 0.877595  0.712624              0.666728
# 866                  0.445974  0.000000              0.126706
# 1827                 0.138735  0.611190              0.234111
#
#       months_since_last_claim  months_since_policy_inception  \
# 6733                 0.558902                       0.955026
# 4793                 0.609888                       0.878201
# 7866                 0.658194                       0.065298
# 866                  0.584760                       0.656097
# 1827                 0.532242                       0.346649
#
#       number_of_open_complaints  number_of_policies  response  \
# 6733                   0.993914            0.000000       0.0
# 4793                   0.000000            0.965080       0.0
# 7866                   0.000000            0.374966       0.0
# 866                    0.000000            0.579350       0.0
# 1827                   0.000000            0.000000       1.0
#
#       employmentstatus  gender  ...  policy_L3  renew_offer_type_Offer2  \
# 6733          0.000000     1.0  ...        1.0                      0.0
# 4793          0.000000     1.0  ...        1.0                      0.0
# 7866          1.000000     1.0  ...        1.0                      0.0
# 866           0.000000     1.0  ...        0.0                      1.0
# 1827          0.321717     0.0  ...        1.0                      1.0
#
#       renew_offer_type_Offer3  renew_offer_type_Offer4  sales_channel_Branch  \
# 6733                      0.0                      0.0                   0.0
# 4793                      1.0                      0.0                   0.0
# 7866                      0.0                      0.0                   0.0
# 866                       0.0                      0.0                   1.0
# 1827                      0.0                      0.0                   0.0
#
#       sales_channel_Call Center  sales_channel_Web  vehicle_class_Luxury  \
# 6733                        0.0                1.0                   0.0
# 4793                        0.0                0.0                   0.0
# 7866                        0.0                0.0                   0.0
# 866                         0.0                0.0                   0.0
# 1827                        0.0                1.0                   0.0
#
#       vehicle_class_SUV  vehicle_class_Two-Door Car
# 6733                1.0                         0.0
# 4793                0.0                         0.0
# 7866                0.0                         0.0
# 866                 0.0                         1.0
# 1827                0.0                         0.0
#
# [5 rows x 36 columns]
#       customer_lifetime_value    income  monthly_premium_auto  \
# 3048                 0.821860  0.000000              0.078607
# 2904                 0.630142  0.866341              0.000000
# 7796                 0.188757  0.741774              0.213965
# 6448                 0.781180  0.898099              0.053309
# 4029                 0.226447  0.000000              0.501145
#
#       months_since_last_claim  months_since_policy_inception  \
# 3048                 0.558902                       0.939855
# 2904                 0.415600                       0.100232
# 7796                 0.532242                       0.611936
# 6448                 0.187402                       0.368453
# 4029                 0.890139                       0.289814
#
#       number_of_open_complaints  number_of_policies  response  \
# 3048                        0.0            0.374966       0.0
# 2904                        0.0            0.374966       0.0
# 7796                        0.0            0.000000       0.0
# 6448                        0.0            0.374966       0.0
# 4029                        0.0            0.000000       0.0
#
#       employmentstatus  gender  ...  policy_L3  renew_offer_type_Offer2  \
# 3048               0.0     1.0  ...        1.0                      1.0
# 2904               1.0     0.0  ...        1.0                      1.0
# 7796               1.0     0.0  ...        1.0                      0.0
# 6448               1.0     0.0  ...        0.0                      1.0
# 4029               0.0     0.0  ...        0.0                      1.0
#
#       renew_offer_type_Offer3  renew_offer_type_Offer4  sales_channel_Branch  \
# 3048                      0.0                      0.0                   0.0
# 2904                      0.0                      0.0                   0.0
# 7796                      1.0                      0.0                   0.0
# 6448                      0.0                      0.0                   0.0
# 4029                      0.0                      0.0                   0.0
#
#       sales_channel_Call Center  sales_channel_Web  vehicle_class_Luxury  \
# 3048                        0.0                0.0                   0.0
# 2904                        0.0                1.0                   0.0
# 7796                        0.0                1.0                   0.0
# 6448                        0.0                0.0                   0.0
# 4029                        0.0                0.0                   0.0
#
#       vehicle_class_SUV  vehicle_class_Two-Door Car
# 3048                0.0                         0.0
# 2904                0.0                         0.0
# 7796                0.0                         1.0
# 6448                0.0                         0.0
# 4029                0.0                         0.0
#
# [5 rows x 36 columns]

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
lm = linear_model.LinearRegression()
lm.fit(X_train_new_scaled_df,y_train)
y_pred_test = lm.predict(X_test_new_scaled_df)
r2_score_test = r2_score(y_test,y_pred_test)

print("The R2 score of the test set is {:.2f}".format(r2_score_test))
# Out:
# The R2 score of the test set is 0.53

# %%
#from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

def linear_model(X1,X2,y1,y2):
    from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error
    from sklearn import linear_model
    lm = linear_model.LinearRegression()
    lm.fit(X1,y1)
    y_pred = lm.predict(X2)
    MAE = mean_absolute_error(y2,y_pred)
    MSE = mean_squared_error(y2,y_pred)
    RMSE = np.sqrt(mean_squared_error(y2,y_pred))
    MAPE = mean_absolute_percentage_error(y2,y_pred)
    R2 = r2_score(y2,y_pred)
    
    dic = {"Error_metric":["MAE","MSE","RMSE","MAPE","R2"],"Value":[round(MAE,2),round(MSE,2),round(RMSE,2),round(MAPE,2),round(R2,2)]}
    value = pd.DataFrame(data = dic)
    return value

# %%
linear_model(X_train_new_scaled_df,X_test_new_scaled_df,y_train,y_test)
# Out:
#   Error_metric     Value
# 0          MAE    119.56
# 1          MSE  24700.27
# 2         RMSE    157.16
# 3         MAPE      1.85
# 4           R2      0.53

# %%
def model_training(X1,X2,y1,y2):
    from sklearn.neighbors import KNeighborsRegressor
    from sklearn.metrics import r2_score
    from sklearn import linear_model
    from sklearn.neural_network import MLPRegressor
    
    lm = linear_model.LinearRegression()
    lm.fit(X1,y1)
    y_pred = lm.predict(X2)
    R2 = r2_score(y2,y_pred)
    
    neigh = KNeighborsRegressor(n_neighbors=6)
    neigh.fit(X1,y1)
    y_pred_2=neigh.predict(X2)
    R2_KN = r2_score(y2,y_pred_2)
    
    regr = MLPRegressor(random_state=1, max_iter=10000).fit(X1,y1)
    regr.predict(X2)
    score = regr.score(X2,y2)
    
    value_list = [R2,R2_KN,score]
    df = pd.DataFrame(data = value_list, index=['Linear Regression','KNeighborsRegressor','MLPRegressor'],columns=['R2 score'])
    
    return df

# %%
model_training(X_train_new_scaled_df,X_test_new_scaled_df,y_train,y_test)
# Out:
#                      R2 score
# Linear Regression    0.532867
# KNeighborsRegressor  0.455488
# MLPRegressor         0.795213

# %% [markdown]
# ### According to the (R2) score, the MLPRegressor model performs the best.
